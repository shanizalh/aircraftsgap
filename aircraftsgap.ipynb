# %%
# Import necessary packages
import pandas as pd
import os
from datetime import date

# %%
# List of column headers
headers = ['Fleet', 'Floc', 'Message type (R/A/G)', 'Error number', 'Functional identifier (FID)', 'Message text', 'Material', 'Sequence']

# Create empty dataframe
combined = pd.DataFrame(columns=headers)

# List of files
directories = os.listdir()
files = [file for file in directories if '.XLS' in file]

# Append all files into dataframe
for f in files:
    data = pd.read_csv(f, sep='\t', skiprows=0)
    combined = combined.append(data, ignore_index=True)

# Remove duplicates and reset index
combined = combined.drop_duplicates()[1:].reset_index()
combined = combined.iloc[:,1:]

# Start row index from 1
combined.index = combined.index + 1
combined
# Out:
#        Fleet    Floc Message type (R/A/G) Error number  \
# 1      ATR72  PK-GAJ                    R           41
# 2    777-300  PK-GIA                    R           41
# 3    777-300  PK-GIA                    R           41
# 4    777-300  PK-GIA                    R           41
# 5    777-300  PK-GIA                    R           41
# 6    777-300  PK-GIA                    R           41
# 7    777-300  PK-GIA                    R           41
# 8    777-300  PK-GIA                    R           41
# 9    777-300  PK-GIA                    R           33
# 10   777-300  PK-GIA                    R           33
# 11   737-800  PK-GNL                    R           33
# 12   737-800  PK-GNL                    R           33
# 13   737-800  PK-GNL                    R           41
# 14   330-300  PK-GPV                    R           41
# 15   330-300  PK-GPV                    R           41
# 16   330-300  PK-GPV                    R           41
# 17   737-800  PK-GMJ                    R           41
# 18   737-800  PK-GFK                    R           41
# 19   737-800  PK-GFK                    R           41
# 20   737-800  PK-GFK                    R           41
# 21   737-800  PK-GNP                    R           41
# 22   737-800  PK-GNP                    R           41
# 23   737-800  PK-GNP                    R           33
# 24   737-800  PK-GNP                    R           41
# 25   737-800  PK-GNP                    R           33
# 26   737-800  PK-GNC                    R           41
# 27     ATR72  PK-GAC                    R           41
# 28     ATR72  PK-GAC                    R           41
# 29     ATR72  PK-GAC                    R           41
# 30     ATR72  PK-GAC                    R           41
# ..       ...     ...                  ...          ...
# 901  737-800  PK-GFG                    R           41
# 902  737-800  PK-GFG                    R           41
# 903  737-800  PK-GFG                    R           41
# 904  737-800  PK-GMM                    R           41
# 905  737-800  PK-GMM                    R           41
# 906  737-800  PK-GMM                    R           41
# 907  737-800  PK-GMM                    A           42
# 908  737-800  PK-GMM                    R           41
# 909  737-800  PK-GMM                    R           41
# 910  737-800  PK-GMM                    R           41
# 911  737-800  PK-GMM                    A           42
# 912  737-800  PK-GNH                    R           33
# 913  737-800  PK-GNH                    A           42
# 914    ATR72  PK-GAQ                    R           41
# 915  CRJ1000  PK-GRL                    R           41
# 916  330-200  PK-GPN                    R           33
# 917  330-200  PK-GPN                    R           41
# 918  330-900  PK-GHE                    R           41
# 919  330-900  PK-GHE                    R           41
# 920  330-900  PK-GHE                    R           41
# 921  330-900  PK-GHE                    R           33
# 922  737-800  PK-GEN                    R           31
# 923  737-800  PK-GEN                    R           31
# 924  737-800  PK-GEN                    A           50
# 925  737-800  PK-GNS                    R           41
# 926  737-800  PK-GNS                    R           41
# 927  737-800  PK-GNJ                    A           42
# 928  737-800  PK-GNJ                    R           33
# 929    ATR72  PK-GAF                    R           41
# 930    ATR72  PK-GAF                    R           41
#
#              Functional identifier (FID)  \
# 1                   262170_ENGINE_FIREXT
# 2                     35_CREW_OXY_BOTTLE
# 3                361107_LRU_HP_SHTOF_VLV
# 4                361107_LRU_HP_SHTOF_VLV
# 5              521200_LRU_BATT_PACK_EMER
# 6              521200_LRU_BATT_PACK_EMER
# 7              521200_LRU_BATT_PACK_EMER
# 8              521200_LRU_BATT_PACK_EMER
# 9              720051_FAN_BLADE_PLATFORM
# 10           772101_LRU_EGT_TRMCPL_PROBE
# 11                      35_CREW_OXY_MASK
# 12                 710002_LRU_CTAI_VALVE
# 13         710002_LRU_IDG_AIR_OIL_COOLER
# 14                          26_FIREX_BCF
# 15                          26_FIREX_BCF
# 16                          26_FIREX_BCF
# 17                26_FIREXT_BOTTLE_CARGO
# 18          492693_LRU_STARTER_GENERATOR
# 19   492693_LRU_WIRING_HARNESS_GENERATOR
# 20                    722100_S_FAN_BLADE
# 21          492693_LRU_STARTER_GENERATOR
# 22          492693_LRU_STARTER_GENERATOR
# 23          492693_LRU_STARTER_GENERATOR
# 24   492693_LRU_WIRING_HARNESS_GENERATOR
# 25   492693_LRU_WIRING_HARNESS_GENERATOR
# 26                            23_ELT_FIX
# 27                243110_EMRGNCY_BATTERY
# 28                   243110_MAIN_BATTERY
# 29                 252120_ATTND_SEAT_FWD
# 30                  262170_ENGINE_FIREXT
# ..                                   ...
# 901               26_FIREXT_BOTTLE_CARGO
# 902                   341101_PITOT_PROBE
# 903                           353000_PBE
# 904                 27_FL_ALT_DRIVE_UNIT
# 905             334202_LDG_LIGHT_ASSY_RH
# 906                         34_TAT_PROBE
# 907                         361151_STRUT
# 908                  491531_ACT_APU_DOOR
# 909         492693_LRU_STARTER_GENERATOR
# 910                        720000_ENGINE
# 911           732140_LRU_SENSOR_TEMP_T12
# 912                     335106_BATT_PACK
# 913      725200_S_SEAL_ROTATING_HPT_REAR
# 914                 262170_ENGINE_FIREXT
# 915            237100_RIPS_TYPE_II_NICAD
# 916                       242151_LRU_IDG
# 917                            323318_GF
# 918                     253150_MICROWAVE
# 919           256241_SLIDE_RAFT_DOOR_1_4
# 920           275134_SLAT_FLAP_CTRL_COMP
# 921               33_BATT_PACK_EMERGENCY
# 922       282200_ACT_ELECTRIC_MOTOR_FUEL
# 923       282200_ACT_ELECTRIC_MOTOR_FUEL
# 924       282200_ACT_ELECTRIC_MOTOR_FUEL
# 925         492693_LRU_STARTER_GENERATOR
# 926  492693_LRU_WIRING_HARNESS_GENERATOR
# 927           710002_LRU_VALVE_PRECOOLER
# 928                   722100_S_FAN_BLADE
# 929               243110_EMRGNCY_BATTERY
# 930                  243110_MAIN_BATTERY
#
#                                           Message text             Material  \
# 1    Structure gap at Functional Location PK-GAJ.26...       472420-2:61423
# 2    Structure gap at Functional Location PK-GIA.35...      806835-01:53655
# 3                  Structure gap at Equipment 12145097      3215302-5:59364
# 4                  Structure gap at Equipment 12145097      3215302-5:59364
# 5    Structure gap at Functional Location PK-GIA.52...       BPAS10-5:1MXA1
# 6    Structure gap at Functional Location PK-GIA.52...       BPAS10-5:1MXA1
# 7    Structure gap at Functional Location PK-GIA.52...       BPAS10-5:1MXA1
# 8    Structure gap at Functional Location PK-GIA.52...       BPAS10-5:1MXA1
# 9    19 object(s) found below superior object 12167...                  NaN
# 10   1 object(s) found below superior object 121677...                  NaN
# 11   3 object(s) found below superior object PK-GNL...                  NaN
# 12   2 object(s) found below superior object 120330...                  NaN
# 13                 Structure gap at Equipment 12033001     UA538551-3:78943
# 14   Structure gap at Functional Location PK-GPV.26...          74-20:D0243
# 15   Structure gap at Functional Location PK-GPV.26...          74-20:D0243
# 16   Structure gap at Functional Location PK-GPV.26...          74-20:D0243
# 17   Structure gap at Functional Location PK-GMJ.26...       473957-4:61423
# 18                 Structure gap at Equipment 12118781       28B545-9:99193
# 19                 Structure gap at Equipment 12118781      3888448-2:64816
# 20                 Structure gap at Equipment 12215840  340-001-026-0:F0301
# 21                 Structure gap at Equipment 12073853       28B545-9:99193
# 22                 Structure gap at Equipment 12073853       28B545-9:99193
# 23   2 object(s) found below superior object 120738...                  NaN
# 24                 Structure gap at Equipment 12073853      3888448-2:64816
# 25   2 object(s) found below superior object 120738...                  NaN
# 26   Structure gap at Functional Location PK-GNC.23...      1152682-2:07217
# 27   Structure gap at Functional Location PK-GAC.24...         1658-6:FB429
# 28   Structure gap at Functional Location PK-GAC.24...        40678-2:F6177
# 29   Structure gap at Functional Location PK-GAC.25...   53701-00-033:F0465
# 30   Structure gap at Functional Location PK-GAC.26...       472420-2:61423
# ..                                                 ...                  ...
# 901  Structure gap at Functional Location PK-GFG.26...       473957-4:61423
# 902  Structure gap at Functional Location PK-GFG.34...        0851HT1:59885
# 903  Structure gap at Functional Location PK-GFG.35...      802300-14:53655
# 904  Structure gap at Functional Location PK-GMM.27...     4221T100-3:81833
# 905  Structure gap at Functional Location PK-GMM.33...      45-0351-4:72914
# 906  Structure gap at Functional Location PK-GMM.34...       102AH2AG:60678
# 907  No corresponding technical object can be found...                  NaN
# 908  Structure gap at Functional Location PK-GMM.49...     R6200M3-13:81039
# 909                Structure gap at Equipment 12051955       28B545-9:99193
# 910  Structure gap at Functional Location PK-GMM.72...   CFM56-7B26/3:58828
# 911  No corresponding technical object can be found...                  NaN
# 912  9 object(s) found below superior object PK-GNH...                  NaN
# 913  No corresponding technical object can be found...                  NaN
# 914  Structure gap at Functional Location PK-GAQ.26...       472420-2:61423
# 915  Structure gap at Functional Location PK-GRL.23...   100-2010-100:06141
# 916  2 object(s) found below superior object 121235...                  NaN
# 917  Structure gap at Functional Location PK-GPN.32...     TY3409-01A:K0377
# 918  Structure gap at Functional Location PK-GHE.25...    400-2384-01:FAPE3
# 919  Structure gap at Functional Location PK-GHE.25...       103052-1:FAPE3
# 920  Structure gap at Functional Location PK-GHE.27...  84333-00-0306:D4829
# 921  9 object(s) found below superior object PK-GHE...                  NaN
# 922  Material MA30A1001:73760 of Equipment 12067929...                  NaN
# 923  Material MA30A1001:73760 of Equipment 12067924...                  NaN
# 924                      Quantity has not been checked                  NaN
# 925                Structure gap at Equipment 12224303       28B545-7:07217
# 926                Structure gap at Equipment 12224303      3888448-2:64816
# 927  No corresponding technical object can be found...                  NaN
# 928  25 object(s) found below superior object 12155...                  NaN
# 929  Structure gap at Functional Location PK-GAF.24...         1658-6:FB429
# 930  Structure gap at Functional Location PK-GAF.24...        40678-2:F6177
#
#     Sequence
# 1          1
# 2          3
# 3          8
# 4          9
# 5          4
# 6          5
# 7          6
# 8          7
# 9          1
# 10         2
# 11         1
# 12         2
# 13         3
# 14         1
# 15         2
# 16         3
# 17         1
# 18         3
# 19         2
# 20         1
# 21         3
# 22         4
# 23         5
# 24         1
# 25         2
# 26         1
# 27         3
# 28         4
# 29         5
# 30         1
# ..       ...
# 901        1
# 902        6
# 903        7
# 904        2
# 905        3
# 906        4
# 907        7
# 908        6
# 909        5
# 910        1
# 911        8
# 912        1
# 913        2
# 914        1
# 915        1
# 916        2
# 917        1
# 918        4
# 919        1
# 920        2
# 921        3
# 922        1
# 923        2
# 924        3
# 925        2
# 926        1
# 927        2
# 928        1
# 929        1
# 930        2
#
# [930 rows x 8 columns]

# %%
# Convert generated dataframe to excel
today = date.today()
today_date = today.strftime('%Y%m%d')
filename = 'zrccm2_' + today_date + '.xlsx'
combined.to_excel(filename)
